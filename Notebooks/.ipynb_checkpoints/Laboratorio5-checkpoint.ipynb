# %% [markdown]
# ## Utilización de la librería FAKER
# ## Datos sintéticos
# *Autor: Luis ALberto García Lezama*

# %%
import pandas as pd
import numpy as np
import random

# %%
# Importamos la librería Faker 
from faker import Faker

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in c:\users\luisi\anaconda3\lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in c:\users\luisi\anaconda3\lib\site-packages (from Faker) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creamos una instancia de Faker 
fake = Faker("es_MX")

# %%
# Generamos datos sintéticos o datos falsos
datos = []
for i in range(100):
    datos.append(
        {
          "id_usuario" : i +1,
          "nombre" : fake.name(),
          "correo" : fake.email(),
          "edad" : random.randint(18,65),
          "seguidores" : random.randint(50,5000),
          "plataforma" : random.choice(["TikTok", "Instagram", "YouTube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                         nombre                          correo  \
# 0            1                 Adriana Acosta             iromero@example.org
# 1            2      Genaro Abel Blanco Acosta       julio-cesar74@example.com
# 2            3  Bruno Cristobal Amador Moreno         solizoliver@example.org
# 3            4                 Raquel Luevano         jaqueline36@example.com
# 4            5     Benjamín Villagómez Alcala         ovillasenor@example.net
# ..         ...                            ...                             ...
# 95          96           Elsa Palomino Nájera  gutierrezjaqueline@example.net
# 96          97           Ofelia Perales Cotto          zacarias94@example.org
# 97          98              Ing. Sergio Armas        jonasvaladez@example.com
# 98          99       Natividad Soto Escamilla        arroyosamuel@example.net
# 99         100        Esteban Fernando Ocasio      maria-teresa97@example.com
#
#     edad  seguidores plataforma
# 0     54        3329     TikTok
# 1     29        3696  Instagram
# 2     18        4570    YouTube
# 3     64        4005  Instagram
# 4     62        3050    YouTube
# ..   ...         ...        ...
# 95    49        3134    YouTube
# 96    20        4275     TikTok
# 97    58        4490    YouTube
# 98    58        3114    YouTube
# 99    60        2020     TikTok
#
# [100 rows x 6 columns]

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   41.110000  2705.910000
# std     29.011492   14.048182  1382.217104
# min      1.000000   18.000000    99.000000
# 25%     25.750000   28.000000  1573.750000
# 50%     50.500000   42.000000  3003.500000
# 75%     75.250000   53.000000  3632.250000
# max    100.000000   65.000000  4987.000000

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario          nombre               correo        edad  \
# count   100.000000             100                  100  100.000000
# unique         NaN             100                  100         NaN
# top            NaN  Adriana Acosta  iromero@example.org         NaN
# freq           NaN               1                    1         NaN
# mean     50.500000             NaN                  NaN   41.110000
# std      29.011492             NaN                  NaN   14.048182
# min       1.000000             NaN                  NaN   18.000000
# 25%      25.750000             NaN                  NaN   28.000000
# 50%      50.500000             NaN                  NaN   42.000000
# 75%      75.250000             NaN                  NaN   53.000000
# max     100.000000             NaN                  NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# top             NaN     TikTok
# freq            NaN         34
# mean    2705.910000        NaN
# std     1382.217104        NaN
# min       99.000000        NaN
# 25%     1573.750000        NaN
# 50%     3003.500000        NaN
# 75%     3632.250000        NaN
# max     4987.000000        NaN

# %%
# Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos como se generan las edades 
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
# Graficar la cantidad de usuarios por plataforma 
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
